# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
out_dir = '/Users/tanshi/Desktop/SIP/'
execfile(out_dir+'plot_routines.py')

# %%
#loading Mv values
Mv = np.loadtxt('Table_Mass_0.6.txt',usecols=(3),unpack=True)
print(Mv)
# Out:
# [18.984 18.491 18.097 17.774 17.51  17.285 17.082 16.883 16.684 16.478
#  16.257 16.012 15.742 15.462 15.178 14.909 14.658 14.222 13.865 13.557
#  13.281 13.023 12.783 12.554 12.342 12.149 11.977 11.834 11.714 11.615
#  11.544 11.476 11.406 11.336 11.27  11.207 11.148 11.09  11.036 10.982
#  10.682 10.241  9.814  9.433  9.19   8.986  8.793  8.616  8.446  8.286
#   8.126  7.968  7.795  7.589  7.388  7.183  6.951]

# %%
# mv = -5logD + 5 + Mv
mv_100 = 5*np.log10(100) - 5 + Mv
mv_200 = 5*np.log10(200) - 5 + Mv
mv_500 = 5*np.log10(500) - 5 + Mv
mv_1000 = 5*np.log10(1000) - 5 + Mv


print(mv_100)
# Out:
# [23.984 23.491 23.097 22.774 22.51  22.285 22.082 21.883 21.684 21.478
#  21.257 21.012 20.742 20.462 20.178 19.909 19.658 19.222 18.865 18.557
#  18.281 18.023 17.783 17.554 17.342 17.149 16.977 16.834 16.714 16.615
#  16.544 16.476 16.406 16.336 16.27  16.207 16.148 16.09  16.036 15.982
#  15.682 15.241 14.814 14.433 14.19  13.986 13.793 13.616 13.446 13.286
#  13.126 12.968 12.795 12.589 12.388 12.183 11.951]

# %%
UB = np.loadtxt('Table_Mass_0.6.txt', usecols=(4),unpack=True)
print(UB)

BV = np.loadtxt('Table_Mass_0.6.txt', usecols=(5),unpack=True)
print(BV)

UV = UB + BV
print(UV)
# Out:
# [ 1.113  0.944  0.813  0.702  0.604  0.522  0.453  0.39   0.33   0.272
#   0.211  0.146  0.075  0.    -0.076 -0.149 -0.216 -0.335 -0.439 -0.515
#  -0.563 -0.591 -0.602 -0.603 -0.597 -0.588 -0.582 -0.582 -0.587 -0.591
#  -0.596 -0.603 -0.616 -0.633 -0.652 -0.672 -0.694 -0.715 -0.736 -0.757
#  -0.87  -1.005 -1.106 -1.166 -1.196 -1.213 -1.225 -1.234 -1.241 -1.247
#  -1.253 -1.257 -1.261 -1.264 -1.268 -1.271 -1.274]
# [ 1.418  1.423  1.384  1.336  1.285  1.234  1.189  1.143  1.099  1.052
#   1.002  0.948  0.887  0.823  0.757  0.694  0.636  0.533  0.445  0.374
#   0.322  0.283  0.255  0.236  0.224  0.215  0.207  0.197  0.187  0.177
#   0.167  0.154  0.138  0.12   0.102  0.082  0.065  0.049  0.034  0.021
#  -0.046 -0.127 -0.193 -0.237 -0.26  -0.275 -0.286 -0.294 -0.301 -0.306
#  -0.312 -0.316 -0.32  -0.324 -0.327 -0.33  -0.333]
# [ 2.531  2.367  2.197  2.038  1.889  1.756  1.642  1.533  1.429  1.324
#   1.213  1.094  0.962  0.823  0.681  0.545  0.42   0.198  0.006 -0.141
# ...

# %%
fig=plt.figure(figsize=(10,10))
plt.scatter(UV,mv_100,c='blue',edgecolors='none',s=10,alpha=0.5)
plt.scatter(UV,mv_200,c='orange',edgecolors='none',s=10,alpha=0.5)
plt.scatter(UV,mv_500,c='red',edgecolors='none',s=10,alpha=0.5)
plt.scatter(UV,mv_1000,c='green',edgecolors='none',s=10,alpha=0.5)

x_array = [-0.2, 1.8, 1.8, -0.2, -0.2]
y_array = [18.7, 18.7, 23.3, 23.3, 18.7]

plt.plot(x_array, y_array)

plt.scatter(0.61,19.79,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.84,22.09,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.73,19.85,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.15,23.37,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.02,22.69,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(-0.25,22.38,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.65,22.42,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.18,22.88,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.17,22.7,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.67,20.88,c='black',edgecolors='none',s=30,alpha=0.5)
plt.scatter(0.88,21.15,c='black',edgecolors='none',s=30,alpha=0.5)

#plt.xlim(-0.1,2)
plt.ylim(30,10)
plt.xlabel('U-V')
plt.ylabel('mv(mag)')
plt.savefig(out_dir+'plotting_mv_whitedwarf_0.6.pdf')
