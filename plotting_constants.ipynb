# %%
import numpy as np
data_dir = './'
script_dir = '/Users/tanshi/Desktop/SIP/'
out_dir = './'

# %%
execfile(script_dir+'plot_routines.py')

# %%
gdn = Table.read('/Users/tanshi/Desktop/SIP/gdn.hdf5')
# Out:
# /anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
gdn_selection = np.where ( \
                          (gdn['WFC3_F160W_FLUX'] > 0) 
                         )
gdn_final = gdn[gdn_selection]
gdn_flux = gdn_final['WFC3_F160W_FLUX']

gdn_mag = gdn['Limiting_Magnitude_F160W']

constant = np.array([])
for i in range(0,35436):
    constant = np.append(constant,gdn_mag[i] + (2.5*np.log10(gdn_flux[i])))
print constant
print np.arange(35436)
# Out:
# [31.97059519 32.32119927 31.15358643 ... 30.13846021 29.81381266
#  29.27430173]
# [    0     1     2 ... 35433 35434 35435]

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(np.arange(35436),constant,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(0,36000)
plt.ylim(20,45)
plt.xlabel('ID')
plt.ylabel('Constant')
plt.savefig('/Users/tanshi/Desktop/SIP/constants_plot')
