# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
out_dir = '/Users/tanshi/Desktop/SIP/'
execfile(out_dir+'plot_routines.py')

# %%
Mv = np.loadtxt('Table_Mass_0.5.txt',usecols=(3),unpack=True)
print(Mv)
# Out:
# [18.78  18.294 17.903 17.585 17.328 17.107 16.904 16.703 16.503 16.293
#  16.069 15.818 15.542 15.255 14.968 14.696 14.442 14.007 13.649 13.34
#  13.061 12.801 12.559 12.328 12.114 11.919 11.746 11.604 11.488 11.397
#  11.324 11.251 11.176 11.104 11.039 10.975 10.914 10.853 10.796 10.741
#  10.422  9.951  9.488  9.047  8.771  8.52   8.285  8.06   7.848  7.64
#   7.421  7.171  6.906  6.648  6.385  6.092  5.76 ]

# %%
UB = np.loadtxt('Table_Mass_0.5.txt', usecols=(4),unpack=True)
print(UB)

BV = np.loadtxt('Table_Mass_0.5.txt', usecols=(5),unpack=True)
print(BV)

UV = UB + BV
print(UV)
# Out:
# [ 1.164  0.984  0.847  0.73   0.628  0.543  0.471  0.406  0.343  0.282
#   0.22   0.152  0.079  0.002 -0.075 -0.148 -0.216 -0.336 -0.44  -0.513
#  -0.558 -0.582 -0.589 -0.586 -0.575 -0.563 -0.555 -0.553 -0.556 -0.559
#  -0.564 -0.573 -0.589 -0.609 -0.631 -0.653 -0.676 -0.698 -0.72  -0.741
#  -0.859 -0.995 -1.099 -1.162 -1.192 -1.21  -1.222 -1.232 -1.239 -1.245
#  -1.251 -1.255 -1.26  -1.263 -1.266 -1.27  -1.272]
# [ 1.462  1.451  1.407  1.357  1.303  1.25   1.202  1.155  1.109  1.06
#   1.009  0.953  0.89   0.824  0.758  0.694  0.636  0.532  0.444  0.373
#   0.322  0.283  0.255  0.236  0.223  0.213  0.204  0.193  0.182  0.171
#   0.16   0.144  0.126  0.106  0.087  0.068  0.051  0.036  0.021  0.009
#  -0.057 -0.136 -0.199 -0.242 -0.264 -0.279 -0.289 -0.297 -0.304 -0.309
#  -0.315 -0.319 -0.323 -0.327 -0.33  -0.333 -0.335]
# [ 2.626  2.435  2.254  2.087  1.931  1.793  1.673  1.561  1.452  1.342
#   1.229  1.105  0.969  0.826  0.683  0.546  0.42   0.196  0.004 -0.14
#  -0.236 -0.299 -0.334 -0.35  -0.352 -0.35  -0.351 -0.36  -0.374 -0.388
#  -0.404 -0.429 -0.463 -0.503 -0.544 -0.585 -0.625 -0.662 -0.699 -0.732
#  -0.916 -1.131 -1.298 -1.404 -1.456 -1.489 -1.511 -1.529 -1.543 -1.554
#  -1.566 -1.574 -1.583 -1.59  -1.596 -1.603 -1.607]

# %%
fig=plt.figure(figsize=(10,10))
plt.scatter(UV, Mv, c='black',edgecolors='none',s=20,alpha=0.5)
plt.ylim(22,4)
plt.xlabel('U-V')
plt.ylabel('Mv(mag)')
# Out:
# Text(0,0.5,'Mv(mag)')

# %%
# UV = [ 2.626  2.435  2.254  2.087  1.931  1.793  1.673  1.561  1.452  1.342
#   1.229  1.105  0.969  0.826  0.683  0.546  0.42   0.196  0.004 -0.14
#  -0.236 -0.299 -0.334 -0.35  -0.352 -0.35  -0.351 -0.36  -0.374 -0.388
#  -0.404 -0.429 -0.463 -0.503 -0.544 -0.585 -0.625 -0.662 -0.699 -0.732
#  -0.916 -1.131 -1.298 -1.404 -1.456 -1.489 -1.511 -1.529 -1.543 -1.554
#  -1.566 -1.574 -1.583 -1.59  -1.596 -1.603 -1.607]

mv = [19.79, 22.09, 19.85, 23.37, 22.69, 22.38, 22.42, 22.88, 22.7, 20.88, 21.15]
maddie_UV = np.array([0.61, 0.84, 0.73, 0.15, 0.02, -0.25, 0.65, 0.18, 0.17, 0.67, 0.88])
Mv_wd = np.array([])
for j in range(len(maddie_UV)):
    for i in range(len(UV)):
        if (maddie_UV[j] < UV[i]) and (maddie_UV[j] > UV[i+1]):
#             x1 = UV[i]
#             y1 = Mv[i]
#             x2 = UV[i+1]
#             y2 = Mv[i+1]
#             x = [x1, x2]
#             y = [y1, y2]
#             plt.scatter(UV, Mv, c='black',edgecolors='none',s=5,alpha=0.5)
#             plt.plot(x, y)
#             plt.ylim(22,4)
            weight1 = ((UV[i] - maddie_UV[j]) / (UV[i] - UV[i+1])) * 100
            weight2 = ((maddie_UV[j] - UV[i+1]) / (UV[i] - UV[i+1])) * 100
            Mv_wd = np.append(Mv_wd, ((Mv[i]*weight2) + (Mv[i+1]*weight1)) / (weight1 + weight2))
            #UV_wd = np.append(UV_wd, (((x1*(UV[i]-x1)) + (weight1)) / ((UV[i]-x1) + (UV[i+1]-x2))))
#             print(UV_wd)
#             for i in range(len(UV_wd)):
#                 Mv_wd = np.append(Mv_wd, )
print(maddie_UV)
print(Mv_wd)
# Out:
# [ 0.61  0.84  0.73  0.15  0.02 -0.25  0.65  0.18  0.17  0.67  0.88]
# [14.82306569 15.2830979  15.06232867 13.92122917 13.67883333 13.00322222
#  14.90248175 13.97716667 13.95852083 14.94218978 15.36337762]

# %%
# mv - Mv = 5logD - 5
distance_wd_pc = np.array([])
distance_wd_km = np.array([])
for i in range(len(mv)):
    distance_wd_pc = np.append(distance_wd_pc, (10 ** (((mv[i] - Mv_wd[i]) + 5) / 5)))
    distance_wd_km = np.append(distance_wd_km, (distance_wd_pc[i] * 3.086e+13))
print(distance_wd_pc)
print(distance_wd_km)
# Out:
# [ 98.48880348 229.81608371  90.68475118 775.8078446  634.21036185
#  750.5083968  318.78923653 603.3463179  560.13902787 154.01465374
#  143.65623349]
# [3.03936448e+15 7.09212434e+15 2.79853142e+15 2.39414301e+16
#  1.95717318e+16 2.31606891e+16 9.83783584e+15 1.86192674e+16
#  1.72858904e+16 4.75289221e+15 4.43323137e+15]

# %%
def fitline(x):
    return 1.95*x+13.5

print 19.79-fitline(0.61)
distance_wd_trend = 10**((mv-fitline(maddie_UV)+5)/5)

print ('Distance in parsecs: ')
print distance_wd_trend
print
print('Distance in km: ')
distance_wd_km_trend = distance_wd_trend * 3.086e+13
print distance_wd_km_trend
# Out:
# 5.1005
# Distance in parsecs:
# [104.73696861 245.69708276  96.67184338 823.18983692 676.39439481
#  747.30863419 339.23448954 639.44029453 593.88177789 163.94568853
#  153.7446457 ]
#
# Distance in km:
# [3.23218285e+15 7.58221197e+15 2.98329309e+15 2.54036384e+16
#  2.08735310e+16 2.30619445e+16 1.04687763e+16 1.97331275e+16
#  1.83271917e+16 5.05936395e+15 4.74455977e+15]

# %%
fig=plt.figure(figsize=(10,10))
plt.scatter(maddie_UV, distance_wd_pc, c='black',edgecolors='none',s=60,alpha=0.5)
plt.scatter(maddie_UV, distance_wd_trend, c='blue',edgecolors='none',s=60,alpha=0.5)

# %%
fig=plt.figure(figsize=(10,10))
plt.scatter(UV, Mv, c='black',edgecolors='none',s=20,alpha=0.5)
plt.ylim(28,-1)
plt.xlabel('U-V')
plt.ylabel('Mv(mag)')
plt.scatter(maddie_UV, Mv_wd, c='blue',edgecolors='none',s=20,alpha=0.5)
x_array = [-0.2, 1.8, 1.8, -0.2, -0.2]
y_array = [18.7, 18.7, 23.3, 23.3, 18.7]
plt.plot(x_array, y_array)

# %%
PMW = [2.3, 0, 1.5, 10.2, 7.7, -2.4, 0, -9.7, 1.8, 0.2, 1.6]
PMW_error = [0.1, 0, 0.4, 0.1, 0.1, 0.2, 0, 0.2, 0.2, 0.2, 0.3]
PMN = [-3.3, 0, -2.4, 6.1, -1.3, -8.8, 0, -15.1, 4.8, -1.3, -2.3]
PMN_error = [0.1, 0, 0.4, 0.1, 0.1, 0.2, 0, 0.2, 0.2, 0.2, 0.2]

PMW_radians_per_sec = np.array([])
PMW_error_radians_per_sec = np.array([])
PMN_radians_per_sec = np.array([])
PMN_error_radians_per_sec = np.array([])


for k in range(len(PMW)):
    PMW_radians_per_sec = np.append(PMW_radians_per_sec, ((PMW[k] / (10 ** 3)) / 206265))
    PMW_error_radians_per_sec = np.append(PMW_error_radians_per_sec, ((PMW_error[k] / (10 ** 3)) / 206265))
    PMN_radians_per_sec = np.append(PMN_radians_per_sec, ((PMN[k] / (10 ** 3)) / 206265))
    PMN_error_radians_per_sec = np.append(PMN_error_radians_per_sec, ((PMN_error[k] / (10 ** 3)) / 206265))

# print(PMW_radians_per_sec)
# print(PMW_error_radians_per_sec)
# print(PMN_radians_per_sec)
# print(PMN_error_radians_per_sec)

print('PMW in radians per sec')
for l in range(len(PMW)):
    print(PMW_radians_per_sec[l], 'error:', PMW_error_radians_per_sec[l])

print

print('PMN in radians per sec')
for m in range(len(PMN)):
    print(PMN_radians_per_sec[m], 'error:', PMN_error_radians_per_sec[m])
# Out:
# PMW in radians per sec
# (1.1150704191210336e-08, 'error:', 4.848132257047973e-10)
# (0.0, 'error:', 0.0)
# (7.2721983855719585e-09, 'error:', 1.939252902819189e-09)
# (4.9450949021889314e-08, 'error:', 4.848132257047973e-10)
# (3.733061837926939e-08, 'error:', 4.848132257047973e-10)
# (-1.1635517416915133e-08, 'error:', 9.696264514095945e-10)
# (0.0, 'error:', 0.0)
# (-4.702688289336532e-08, 'error:', 9.696264514095945e-10)
# (8.72663806268635e-09, 'error:', 9.696264514095945e-10)
# (9.696264514095945e-10, 'error:', 9.696264514095945e-10)
# (7.757011611276756e-09, 'error:', 1.4544396771143916e-09)
#
# PMN in radians per sec
# (-1.599883644825831e-08, 'error:', 4.848132257047973e-10)
# (0.0, 'error:', 0.0)
# (-1.1635517416915133e-08, 'error:', 1.939252902819189e-09)
# (2.9573606767992628e-08, 'error:', 4.848132257047973e-10)
# (-6.3025719341623635e-09, 'error:', 4.848132257047973e-10)
# (-4.266356386202216e-08, 'error:', 9.696264514095945e-10)
# (0.0, 'error:', 0.0)
# (-7.320679708142437e-08, 'error:', 9.696264514095945e-10)
# (2.3271034833830266e-08, 'error:', 9.696264514095945e-10)
# (-6.3025719341623635e-09, 'error:', 9.696264514095945e-10)
# (-1.1150704191210336e-08, 'error:', 9.696264514095945e-10)

# %%
print('PMW in km per sec')
for i in range(len(PMW)):
    print(PMW_radians_per_sec[i] * distance_wd_km[i], 'error:', PMW_error_radians_per_sec[i] * distance_wd_km[i])

print

print('PMN in km per sec')
for j in range(len(PMN)):
    print(PMN_radians_per_sec[j] * distance_wd_km[j], 'error:', PMN_error_radians_per_sec[j] * distance_wd_km[j])
# Out:
# PMW in km per sec
# (33891054.19330119, 'error:', 1473524.0953609217)
# (0.0, 'error:', 0.0)
# (20351475.68524441, 'error:', 5427060.182731844)
# (1183926438.6157484, 'error:', 11607121.947213221)
# (730624849.6006049, 'error:', 9488634.410397466)
# (-269486601.7030768, 'error:', 22457216.808589738)
# (0.0, 'error:', 0.0)
# (-875606106.1890144, 'error:', 18053734.148227107)
# (150847709.11275545, 'error:', 16760856.568083938)
# (4608530.011800458, 'error:', 4608530.011800458)
# (34388627.1781688, 'error:', 6447867.59590665)
#
# PMN in km per sec
# (-48626295.14691042, 'error:', 1473524.0953609217)
# (0.0, 'error:', 0.0)
# (-32562361.096391056, 'error:', 5427060.182731844)
# (708034438.7800063, 'error:', 11607121.947213221)
# (-123352247.33516704, 'error:', 9488634.410397466)
# (-988117539.5779485, 'error:', 22457216.808589738)
# (0.0, 'error:', 0.0)
# (-1363056928.1911464, 'error:', 18053734.148227107)
# (402260557.6340145, 'error:', 16760856.568083938)
# (-29955445.07670297, 'error:', 4608530.011800458)
# (-49433651.56861765, 'error:', 4298578.3972711)
