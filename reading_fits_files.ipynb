# %%
script_dir = '/Users/tanshi/Desktop/SIP/'
from astropy.io import fits

# %%
hdu_list = fits.open('zspec.c2a.fits')

# %%
hdu_list.info()
# Out:
# Filename: zspec.c2a.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     91   34R x 35C   [4A, 17A, 5A, 2A, 3A, 10A, D, E, E, E, J, E, 21A, 10J, 35E, 35E, 595A, J, 10E, E, E, I, 51A, 11A, 11A, I, E, E, 33A, 34A, 26A, A, E, E, E]

# %%
hdu = hdu_list[1]
# print(hdu)
# hdu.data.shape

# %%
#hdu.header['TTYPE14']

# %%
image_data = hdu.data
print(image_data)
# Out:
# [('STAR', 'HD237846 F8', '123', '0', 'c2a', '2017-03-04', 57816.350311, -3.3276081e-03, -1.0000000e+00,  0.7560583 , 7444, 0., 'deimos_templates.fits', [ 6, -1, -1, -1, -1, -1, -1, -1, -1, -1], [7.56058276e-01, 7.58558750e-01, 7.58760273e-01, 7.59099364e-01, 7.59351909e-01, 7.59712458e-01, 7.59986877e-01, 7.60173559e-01, 7.60201156e-01, 7.60322452e-01, 7.60337472e-01, 7.60363042e-01, 7.60534704e-01, 7.60547042e-01, 7.60561168e-01, 7.60634303e-01, 1.55255556e-01, 7.60671854e-01, 7.60682106e-01, 7.60684073e-01, 7.60714412e-01, 7.60716856e-01, 7.60751367e-01, 7.60755062e-01, 7.60770977e-01, 7.60814428e-01, 7.60833502e-01, 7.60846615e-01, 7.60854840e-01, 7.60887921e-01, 7.60889590e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00], [-3.32760811e-03, -3.32760811e-03, -2.66611576e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.32760811e-03, -3.
# ...

# %%
from IPython.display import Image
Image("hdu_list")
#plt.imshow(hdu.data[1::], origin='lower')

# %%
hdu_list.close()

# %% [markdown]
# ###
